# %%
# %matplotlib inline

# %%
import urllib2

# %%
f = urllib2.urlopen('http://www.diamond.ac.uk/resources/templating-kit/themes/diamond-lite/img/topmenulogo.png')

# %%
import matplotlib.pyplot as plt
image = plt.imread(f)
plt.imshow(image)
